# %% [markdown]
# ### Importando o pandas com o alias pd

# %%
import pandas as pd

# %%
df = pd.read_csv('./covid_14_out.csv',error_bad_lines=False)
# Out:
# b'Skipping line 22888: expected 17 fields, saw 18\nSkipping line 22889: expected 17 fields, saw 18\nSkipping line 22890: expected 17 fields, saw 18\nSkipping line 22891: expected 17 fields, saw 18\nSkipping line 22892: expected 17 fields, saw 18\nSkipping line 22893: expected 17 fields, saw 18\nSkipping line 22894: expected 17 fields, saw 18\nSkipping line 22895: expected 17 fields, saw 18\nSkipping line 22896: expected 17 fields, saw 18\nSkipping line 22897: expected 17 fields, saw 18\nSkipping line 22898: expected 17 fields, saw 18\nSkipping line 22899: expected 17 fields, saw 18\nSkipping line 22900: expected 17 fields, saw 18\nSkipping line 22901: expected 17 fields, saw 18\nSkipping line 22902: expected 17 fields, saw 18\nSkipping line 22903: expected 17 fields, saw 18\nSkipping line 22904: expected 17 fields, saw 18\nSkipping line 22905: expected 17 fields, saw 18\nSkipping line 22906: expected 17 fields, saw 18\nSkipping line 22907: expected 17 fields, saw 18\nSkipping line 22
# ...

# %%
df.head(10)
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 5  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 6  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 7  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 8  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 9  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2020-02-25          9       210147125.0               0           0
# ...
